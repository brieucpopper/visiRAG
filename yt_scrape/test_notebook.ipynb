# %%
# Download a video's audio from YouTube

from pytubefix import YouTube
from pytubefix.cli import on_progress
 
url = "https://www.youtube.com/watch?v=qQbOEIhmf8s"
 
yt = YouTube(url, on_progress_callback = on_progress)
print(yt.title)
 
ys = yt.streams.get_audio_only()
ys.download(mp3=True)
# Out:
# Rolling In the Deep - Summer House Remix
#  ↳ |████████████████████████████████████████████| 100.0%
# '/home/bpopper/gtCode/visiRAG/yt_scrape/Rolling In the Deep - Summer House Remix.mp3'

# %%
from pytubefix import YouTube

yt = YouTube('https://www.youtube.com/watch?v=qQbOEIhmf8s')
subtitles = yt.captions

print(subtitles)
# Out:
# {'a.en': <Caption lang="English (auto-generated)" code="a.en">}

# %%
from pytubefix import YouTube
 

yt = YouTube('https://www.youtube.com/watch?v=qQbOEIhmf8s')

caption = yt.captions.get_by_language_code('a.en')
print(caption.generate_srt_captions())
# Out:
# 1
# 00:00:02,050 --> 00:00:08,880
# [Music]
#
# 2
# 00:00:04,520 --> 00:00:11,480
# there's a fire starting in my heart we
#
# 3
# 00:00:08,880 --> 00:00:16,080
# cheing a fever pit it's bringing me out
#
# 4
# 00:00:11,480 --> 00:00:19,680
# the dark finally I can see you crystal
#
# 5
# 00:00:16,080 --> 00:00:24,119
# CLE go ahead and stout me out and I'll
#
# 6
# 00:00:19,680 --> 00:00:27,800
# your sh see how I leave with every piece
#
# 7
# 00:00:24,119 --> 00:00:32,200
# of you don't underestimate the things
#
# 8
# 00:00:27,800 --> 00:00:35,879
# that I will do there's sa fire starting
#
# 9
# 00:00:32,200 --> 00:00:37,800
# in my heart reaching a fever bit and is
#
# 10
# 00:00:35,879 --> 00:00:42,800
# bringing me out the
#
# 11
# 00:00:37,800 --> 00:00:45,960
# dark the scars of Your Love remind me of
#
# 12
# 00:00:42,800 --> 00:00:49,559
# us they keep me thinking that we almost
#
# 13
# 00:00:45,960 --> 00:00:53,600
# add it all the scars of Your Love they
#
# 14
# 00:00:49,559 --> 00:00:56,640
# leave me breathless I can't help feeling
#
# 15
# 00:00:53,600 --> 00:00:56,640
# we could have had
#
# 16
# 00:00:57,600 --> 00:01:02,079
# it in the
#
# 17
# 00:00:59,990 --> 00:01:04,800
# [Music]
#
# 18
# 00:01:02,079 --> 00:01:04,800
# you have my
#
# 19
# 00:01:06,000 --> 00:01:10,880
# heart you
#
# 20
# 00:01:08,040 --> 00:01:16,040
# [Music]
#
# 21
# 00:01:10,880 --> 00:01:18,360
# it baby I have no story to be told but
#
# 22
# 00:01:16,040 --> 00:01:22,240
# I've every one on you and I'm going to
#
# 23
# 00:01:18,360 --> 00:01:26,000
# make your head burn think of me in the
#
# 24
# 00:01:22,240 --> 00:01:29,030
# depths of your despair make it home down
#
# 25
# 00:01:26,000 --> 00:01:30,320
# there is M your won't be Shar
#
# 26
# 00:01:29,030 --> 00:01:34,439
# [Music]
#
# 27
# 00:01:30,320 --> 00:01:37,759
# of Your Love remind me of us they keep
#
# 28
# 00:01:34,439 --> 00:01:41,240
# me thinking that we almost had it all
#
# 29
# 00:01:37,759 --> 00:01:44,640
# the scars of Your Love they leave me
#
# 30
# 00:01:41,240 --> 00:01:47,159
# breathless I can't help feeling we could
#
# 31
# 00:01:44,640 --> 00:01:47,159
# have had
#
# 32
# 00:01:48,159 --> 00:01:51,399
# it in
#
# 33
# 00:01:51,640 --> 00:01:56,560
# the you have my heart and
#
# 34
# 00:02:01,360 --> 00:02:05,000
# could have had
#
# 35
# 00:02:02,040 --> 00:02:08,240
# [Music]
#
# 36
# 00:02:05,000 --> 00:02:08,240
# it in
#
# 37
# 00:02:08,360 --> 00:02:18,040
# the you have my heart and
#
# 38
# 00:02:11,680 --> 00:02:21,760
# said head but you played it with the
#
# 39
# 00:02:18,040 --> 00:02:25,760
# beating throw your soul through every
#
# 40
# 00:02:21,760 --> 00:02:30,160
# Open Door count your blessings to find
#
# 41
# 00:02:25,760 --> 00:02:33,760
# what you look for turn my sorrow into to
#
# 42
# 00:02:30,160 --> 00:02:35,680
# treasure go you pay me back and kind of
#
# 43
# 00:02:33,760 --> 00:02:37,959
# reap just watch you
#
# 44
# 00:02:35,680 --> 00:02:42,239
# so
#
# 45
# 00:02:37,959 --> 00:02:46,480
# wish we could have had it
#
# 46
# 00:02:42,239 --> 00:02:46,480
# all we could have had it
#
# 47
# 00:02:48,760 --> 00:02:54,560
# all all all we could have had
#
# 48
# 00:02:55,560 --> 00:03:02,959
# it in
#
# 49
# 00:02:58,200 --> 00:03:02,959
# the rolling you have my heart
#
# 50
# 00:03:03,720 --> 00:03:09,000
# and and you it to
#
# 51
# 00:03:11,450 --> 00:03:14,580
# [Music]
#
# 52
# 00:03:15,879 --> 00:03:19,560
# the you have my
#
# 53
# 00:03:20,560 --> 00:03:29,560
# heart but you played it you played it
#
# 54
# 00:03:23,879 --> 00:03:29,560
# you played it you play it to the beat
# /tmp/ipykernel_12923/339831997.py:6: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   caption = yt.captions.get_by_language_code('a.en')
